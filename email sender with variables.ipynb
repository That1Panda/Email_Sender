# %%
# Import modules
import smtplib, ssl
## email.mime subclasses
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
## The pandas library is only for generating the current date, which is not necessary for sending emails
import pandas as pd
from email.mime.application import MIMEApplication
import pandas as pd
from time import sleep
import numpy as np
import imghdr

# %%
new_code=0
html = f'''
<html>
    <body>
        <p>Dear ,</p>
        <p>We hope this email finds you well. I am writing to let you know that the code that will be used for your team's code submission has been updated. The new code that you will use for your submission is <b>{new_code}</b>.</p>
        <br>
        <p>If you have any questions or concerns, please don't hesitate to reach out to us. We are here to assist you in any way that we can.</p>
        <br>
        <p>Thank you for your cooperation and understanding. We look forward to a successful competition.</p>
        <br>
        <p>Best regards,</p>
        <p>Mohammed Khaled | Technical Team<br>
        STP</p>
    </body>
</html>
'''

# %%
def attach_file_to_email(email_message, filename, extra_headers=None):
    # Open the attachment file for reading in binary mode, and make it a MIMEApplication class
    with open(filename, "rb") as f:
        file_attachment = MIMEApplication(f.read())
    # Add header/name to the attachments    
    file_attachment.add_header(
        "Content-Disposition",
        f"attachment; filename= {filename}",
    )
    # Set up the input extra_headers for img
      ## Default is None: since for regular file attachments, it's not needed
      ## When given a value: the following code will run
         ### Used to set the cid for image
    if extra_headers is not None:
        for name, value in extra_headers.items():
            file_attachment.add_header(name, value)
    # Attach the file to the message
    email_message.attach(file_attachment)

# %%
# Set up the email addresses and password. Please replace below with your email address and password

email_sender="stp23.official@gmail.com"
email_rec="pandahd75@gmail.com"
password="lihtyygyybgooino"


# Generate today's date to be included in the email Subject
#date_str = pd.Timestamp.today().strftime('%Y-%m-%d')

# Create a MIMEMultipart class, and set up the From, To, Subject fields
email_message = MIMEMultipart()
email_message['From'] = email_sender
email_message['To'] = email_rec
email_message['Subject'] = "Team Code Submission | Machathon 4.0"

# Attach the html doc defined earlier, as a MIMEText html content type to the MIME message
email_message.attach(MIMEText(html, "html"))

attach_file_to_email(email_message, 'STP logo.png', {'Content-ID': '<STP>'})


# Convert it as a string
email_string = email_message.as_string()

# %%
# df=pd.read_csv("participant (1).csv")
# emails1=list(set(df["gmona5094@gmail.com"].values))[1:]
# df2=pd.read_csv("audiance.csv")
# emails2=list(set(df2["abdelrahman119@gmail.com"].values))
# emails=list(set(emails1+emails2))
# pd.Series(emails).to_csv("final_emails.csv",index=False)

# %%
# emails=pd.read_csv("Team_Leaders.csv")
# emails=list(emails["email"].values)
# emails[:10]

# %%
emails=["hanaayman.2432002@gmail.com","naghamfakhreldin@gmail.com","maryam_abdelmonem@hotmail.com","ysfm2002@gmail.com","nourhanatef799@gmail.com","momenibrahim346@gmail.com","farah.nasr27@gmail.com","Noursherif858@gmail.com","mohamedmohys@gmail.com","pandahd75@gmail.com","Mzain.7@yahoo.com","Maishahin438@gmail.com","hazemelsheakh12@gmail.com","youssefwaelz15@gmail.com","ahmedassyk.k@gmail.com","hany.noran10@gmail.com","pandaclashingcoc@gmail.com","ayaawd144@gmail.com"]
passes=["hanaayman","naghamfakhreldin","maryam_abdelmonem","ysfm2002","nourhanatef799","momenibrahim346","farah.nasr27","Noursherif858","mohamedmohys","pandahd75","Mzain.7","Maishahin438","hazemelsheakh12","youssefwaelz15","ahmedassyk.k","hany.noran10","pandaclashingcoc","ayaawd144"]

# %%
# emails2=pd.read_csv("members.csv")
# emails2=list(emails2["01114935875m@gmail.com"].values)

# %%
# len(emails2)

# %%
# members_emails=set(emails2)-set(emails).intersection(emails2)

# %% [markdown]
# # Member rejection emails

# %%
# df=pd.read_csv("Members Recruitment 23 - Engineering -Final for rejection.csv")
# rejected_emails=list(df["email"].values)
# len(rejected_emails)

# %%
# rejected_emails

# %%
# rej=list(set(rejected_emails)-set(["yousseffekramy@gmail.com","asamehahmed894@gmail.com","Omar.m.bayoumi@gmail.com","seragahmad85@gmail.com",'marawanelkhateeb77@gmail.com',"mahmoudagouz58@gmail.com"]))
# rej

# %% [markdown]
# -------------------------------------

# %% [markdown]
# # -------------------------------------

# %%
context = ssl.create_default_context()

with smtplib.SMTP_SSL("smtp.gmail.com",465,context=context) as smtp:
    smtp.login(email_sender,password)
    counter=0
    new_code=0
    for email in emails:
        try:
            smtp.sendmail(email_sender,email,email_string)
            print(counter)
            print(email)
            print("-------")
            counter+=1
            new_code+=1
            html = f'''
                    <html>
                        <body>
                            <p>Dear ,</p>
                            <p>We hope this email finds you well. I am writing to let you know that the code that will be used for your team's code submission has been updated. The new code that you will use for your submission is <b>{passes[counter]}</b>.</p>
                            <br>
                            <p>If you have any questions or concerns, please don't hesitate to reach out to us. We are here to assist you in any way that we can.</p>
                            <br>
                            <p>Thank you for your cooperation and understanding. We look forward to a successful competition.</p>
                            <br>
                            <p>Best regards,</p>
                            <p>Mohammed Khaled | Technical Team<br>
                            STP</p>
                        </body>
                    </html>
                '''
            sleep(2)
        except:
            print("Error: Didnt Send")
# Out:
# 0
# hanaayman.2432002@gmail.com
# -------
# Error: Didnt Send
# 1
# naghamfakhreldin@gmail.com
# -------
# Error: Didnt Send
# 2
# maryam_abdelmonem@hotmail.com
# -------
# Error: Didnt Send
# 3
# ysfm2002@gmail.com
# -------
# Error: Didnt Send
# 4
# nourhanatef799@gmail.com
# -------
# Error: Didnt Send
# 5
# momenibrahim346@gmail.com
# -------
# Error: Didnt Send
# 6
# farah.nasr27@gmail.com
# -------
# Error: Didnt Send
# 7
# Noursherif858@gmail.com
# -------
# Error: Didnt Send
# 8
# mohamedmohys@gmail.com
# -------
# Error: Didnt Send
# 9
# pandahd75@gmail.com
# -------
# Error: Didnt Send
# 10
# Mzain.7@yahoo.com
# -------
# Error: Didnt Send
# 11
# Maishahin438@gmail.com
# -------
# Error: Didnt Send
# 12
# hazemelsheakh12@gmail.com
# -------
# Error: Didnt Send
# 13
# youssefwaelz15@gmail.com
# -------
# Error: Didnt Send
# 14
# ahmedassyk.k@gmail.com
# -------
# Error: Didnt Send
# 15
# hany.noran10@gmail.com
# -------
# Error: Didnt Send
# 16
# pandaclashingcoc@gmail.com
# ...

# %%
list(members_emails)[185:400]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23612/1611996634.py in <module>
# ----> 1 list(members_emails)[185:400]
#
# NameError: name 'members_emails' is not defined

# %%
context = ssl.create_default_context()
with smtplib.SMTP_SSL("smtp.gmail.com",465,context=context) as smtp:
    smtp.login(email_sender,password)
    counter=0
    new_code=0
    smtp.sendmail(email_sender,"pandaclashingcoc@gmail.com",email_string)
    print(counter)
    
    print("-------")
#     counter=0
    new_code+=1
    html = f'''
            <html>
                <body>
                    <p>Dear ,</p>
                    <p>We hope this email finds you well. I am writing to let you know that the code that will be used for your team's code submission has been updated. The new code that you will use for your submission is <b>{passes[counter]}</b>.</p>
                    <br>
                    <p>If you have any questions or concerns, please don't hesitate to reach out to us. We are here to assist you in any way that we can.</p>
                    <br>
                    <p>Thank you for your cooperation and understanding. We look forward to a successful competition.</p>
                    <br>
                    <p>Best regards,</p>
                    <p>Mohammed Khaled | Technical Team<br>
                    STP</p>
                </body>
            </html>
        '''
# Out:
# 0
# -------

# %%
counter=7
html = f'''
        <html>
            <body>
                <p>Dear ,</p>
                <p>We hope this email finds you well. I am writing to let you know that the code that will be used for your team's code submission has been updated. The new code that you will use for your submission is <b>{passes[counter]}</b>.</p>
                <br>
                <p>If you have any questions or concerns, please don't hesitate to reach out to us. We are here to assist you in any way that we can.</p>
                <br>
                <p>Thank you for your cooperation and understanding. We look forward to a successful competition.</p>
                <br>
                <p>Best regards,</p>
                <p>Mohammed Khaled | Technical Team<br>
                STP</p>
            </body>
        </html>
    '''
# Create a MIMEMultipart class, and set up the From, To, Subject fields
email_message = MIMEMultipart()
email_message['From'] = email_sender
email_message['To'] = email_rec
email_message['Subject'] = "Team Code Submission | Machathon 4.0"

# Attach the html doc defined earlier, as a MIMEText html content type to the MIME message
email_message.attach(MIMEText(html, "html"))

attach_file_to_email(email_message, 'STP logo.png', {'Content-ID': '<STP>'})


# Convert it as a string
email_string = email_message.as_string()

# %%
context = ssl.create_default_context()
with smtplib.SMTP_SSL("smtp.gmail.com",465,context=context) as smtp:
    smtp.login(email_sender,password)
    counter=0
    new_code=0
    smtp.sendmail(email_sender,"pandaclashingcoc@gmail.com",email_string)
    print(counter)
    
    print("-------")
#     counter=0
    new_code+=1
    html = f'''
            <html>
                <body>
                    <p>Dear ,</p>
                    <p>We hope this email finds you well. I am writing to let you know that the code that will be used for your team's code submission has been updated. The new code that you will use for your submission is <b>{passes[counter]}</b>.</p>
                    <br>
                    <p>If you have any questions or concerns, please don't hesitate to reach out to us. We are here to assist you in any way that we can.</p>
                    <br>
                    <p>Thank you for your cooperation and understanding. We look forward to a successful competition.</p>
                    <br>
                    <p>Best regards,</p>
                    <p>Mohammed Khaled | Technical Team<br>
                    STP</p>
                </body>
            </html>
        '''
# Out:
# 0
# -------

# %% [markdown]
# # Competitors emails Test

# %%
# Import modules
import smtplib, ssl
## email.mime subclasses
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
## The pandas library is only for generating the current date, which is not necessary for sending emails
import pandas as pd
from email.mime.application import MIMEApplication
import pandas as pd
from time import sleep
import numpy as np
import imghdr

# %%
emails=["hanaayman.2432002@gmail.com","naghamfakhreldin@gmail.com","maryam_abdelmonem@hotmail.com","ysfm2002@gmail.com","nourhanatef799@gmail.com","momenibrahim346@gmail.com","farah.nasr27@gmail.com","Noursherif858@gmail.com","mohamedmohys@gmail.com","pandahd75@gmail.com","Mzain.7@yahoo.com","Maishahin438@gmail.com","hazemelsheakh12@gmail.com","youssefwaelz15@gmail.com","ahmedassyk.k@gmail.com","hany.noran10@gmail.com","pandaclashingcoc@gmail.com","ayaawd144@gmail.com"]
passes=["hanaayman","naghamfakhreldin","maryam_abdelmonem","ysfm2002","nourhanatef799","momenibrahim346","farah.nasr27","Noursherif858","mohamedmohys","pandahd75","Mzain.7","Maishahin438","hazemelsheakh12","youssefwaelz15","ahmedassyk.k","hany.noran10","pandaclashingcoc","ayaawd144"]

# %%
def attach_file_to_email(email_message, filename, extra_headers=None):
    # Open the attachment file for reading in binary mode, and make it a MIMEApplication class
    with open(filename, "rb") as f:
        file_attachment = MIMEApplication(f.read())
    # Add header/name to the attachments    
    file_attachment.add_header(
        "Content-Disposition",
        f"attachment; filename= {filename}",
    )
    # Set up the input extra_headers for img
      ## Default is None: since for regular file attachments, it's not needed
      ## When given a value: the following code will run
         ### Used to set the cid for image
    if extra_headers is not None:
        for name, value in extra_headers.items():
            file_attachment.add_header(name, value)
    # Attach the file to the message
    email_message.attach(file_attachment)

# %%
counter=0
html = f'''
        <html>
            <body>
                <p>Dear <b>{emails[counter]}</b>,</p>
                <p>We hope this email finds you well. I am writing to let you know that the code that will be used for your team's code submission has been updated. The new code that you will use for your submission is <b>{passes[counter]}</b>.</p>
                <br>
                <p>If you have any questions or concerns, please don't hesitate to reach out to us. We are here to assist you in any way that we can.</p>
                <br>
                <p>Thank you for your cooperation and understanding. We look forward to a successful competition.</p>
                <br>
                <p>Best regards,</p>
                <p>Mohammed Khaled | Technical Team<br>
                STP</p>
            </body>
        </html>
    '''
# Create a MIMEMultipart class, and set up the From, To, Subject fields
email_message = MIMEMultipart()
email_message['From'] = email_sender
email_message['To'] = email_rec
email_message['Subject'] = "Team Code Submission | Machathon 4.0"

# Attach the html doc defined earlier, as a MIMEText html content type to the MIME message
email_message.attach(MIMEText(html, "html"))

attach_file_to_email(email_message, 'STP logo.png', {'Content-ID': '<STP>'})


# Convert it as a string
email_string = email_message.as_string()

# %%
context = ssl.create_default_context()

with smtplib.SMTP_SSL("smtp.gmail.com",465,context=context) as smtp:
    smtp.login(email_sender,password)
    for email in emails:
        try:
            smtp.sendmail(email_sender,email,email_string)
            print(counter)
            print(email)
            print("-------")
            counter+=1
             
            html = f'''
                    <html>
                        <body>
                            <p>Dear <b>{emails[counter]}</b>,</p>
                            <p>We hope this email finds you well. I am writing to let you know that the code that will be used for your team's code submission has been updated. The new code that you will use for your submission is <b>{passes[counter]}</b>.</p>
                            <br>
                            <p>If you have any questions or concerns, please don't hesitate to reach out to us. We are here to assist you in any way that we can.</p>
                            <br>
                            <p>Thank you for your cooperation and understanding. We look forward to a successful competition.</p>
                            <br>
                            <p>Best regards,</p>
                            <p>Mohammed Khaled | Technical Team<br>
                            STP</p>
                        </body>
                    </html>
                '''
            # Create a MIMEMultipart class, and set up the From, To, Subject fields
            email_message = MIMEMultipart()
            email_message['From'] = email_sender
            email_message['To'] = email_rec
            email_message['Subject'] = "Team Code Submission | Machathon 4.0"

            # Attach the html doc defined earlier, as a MIMEText html content type to the MIME message
            email_message.attach(MIMEText(html, "html"))

            attach_file_to_email(email_message, 'STP logo.png', {'Content-ID': '<STP>'})


            # Convert it as a string
            email_string = email_message.as_string()

            sleep(0.3)
        except:
            print("Error: Didnt Send")
# Out:
# 0
# hanaayman.2432002@gmail.com
# -------
# 1
# naghamfakhreldin@gmail.com
# -------
# 2
# maryam_abdelmonem@hotmail.com
# -------
# 3
# ysfm2002@gmail.com
# -------
# 4
# nourhanatef799@gmail.com
# -------
# 5
# momenibrahim346@gmail.com
# -------
# 6
# farah.nasr27@gmail.com
# -------
# 7
# Noursherif858@gmail.com
# -------
# 8
# mohamedmohys@gmail.com
# -------
# 9
# pandahd75@gmail.com
# -------
# 10
# Mzain.7@yahoo.com
# -------
# 11
# Maishahin438@gmail.com
# -------
# 12
# hazemelsheakh12@gmail.com
# -------
# 13
# youssefwaelz15@gmail.com
# -------
# 14
# ahmedassyk.k@gmail.com
# -------
# 15
# hany.noran10@gmail.com
# -------
# 16
# pandaclashingcoc@gmail.com
# -------
# 17
# ayaawd144@gmail.com
# -------
# Error: Didnt Send

# %% [markdown]
# # Competition email real

# %%
# Import modules
import smtplib, ssl
## email.mime subclasses
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
## The pandas library is only for generating the current date, which is not necessary for sending emails
import pandas as pd
from email.mime.application import MIMEApplication
import pandas as pd
from time import sleep
import numpy as np
import imghdr

# %%
def attach_file_to_email(email_message, filename, extra_headers=None):
    # Open the attachment file for reading in binary mode, and make it a MIMEApplication class
    with open(filename, "rb") as f:
        file_attachment = MIMEApplication(f.read())
    # Add header/name to the attachments    
    file_attachment.add_header(
        "Content-Disposition",
        f"attachment; filename= {filename}",
    )
    # Set up the input extra_headers for img
      ## Default is None: since for regular file attachments, it's not needed
      ## When given a value: the following code will run
         ### Used to set the cid for image
    if extra_headers is not None:
        for name, value in extra_headers.items():
            file_attachment.add_header(name, value)
    # Attach the file to the message
    email_message.attach(file_attachment)

# %%
data=pd.read_csv("Team_Leaders.csv")
data
# Out:
#                       user_name       phone  \
# 0                    Ali Khaled  1118869043
# 1                   Yassin Alaa  1066653279
# 2                   Saraa Gomaa  1020122272
# 3   Abdelrahman Hesham Elhawary  1012737779
# 4                 Salah Soliman  1099899110
# ..                          ...         ...
# 91        Abdelrahman Wael Atef         NaN
# 92        Ahmed Ashraf Marzouk          NaN
# 93  Mohamed Shaban Ahmed Harb           NaN
# 94                  Ahmed Gamal         NaN
# 95           David Wagih Roshdy         NaN
#
#                                 email                  faculty  \
# 0              Khaledhod111@gmail.com  Faculty of engineering
# 1                yaboulnour@yahoo.com             Engineering
# 2                  sa.gomaa@nu.edu.eg             Engineering
# 3   abdelrahman.elhawary451@gmail.com              Engineering
# 4            salahsoliman96@gmail.com              Engineering
# ...

# %%
emails=list(data["email"].values)
user=list(data["user_name"].values)
users=[x.split()[0] for x in user]
new_code=list(data["pass"].values)

# %%
counter=0
html = f'''
        <html>
            <body>
                <p>Dear <b>{users[counter]}</b>,</p>
                <p>We hope this email finds you well. I am writing to let you know that the code that will be used for your team's code submission has been updated. The new code that you will use for your submission is <b>{new_code[counter]}</b>.</p>
                <br>
                <p>If you have any questions or concerns, please don't hesitate to reach out to us using Slack. We are here to assist you in any way that we can.</p>
                <br>
                <p>Thank you for your cooperation and understanding.</p>
                <br>
                <p>Best regards,</p>
                <p>Panda | Technical Team<br>
                STP</p>
            </body>
        </html>
    '''
# Create a MIMEMultipart class, and set up the From, To, Subject fields
email_message = MIMEMultipart()
email_message['From'] = email_sender
email_message['To'] = email_rec
email_message['Subject'] = "Team Code Submission | Machathon 4.0"

# Attach the html doc defined earlier, as a MIMEText html content type to the MIME message
email_message.attach(MIMEText(html, "html"))

attach_file_to_email(email_message, 'STP logo.png', {'Content-ID': '<STP>'})


# Convert it as a string
email_string = email_message.as_string()

# %%
html
# Out:
# "\n        <html>\n            <body>\n                <p>Dear <b>Ali</b>,</p>\n                <p>We hope this email finds you well. I am writing to let you know that the code that will be used for your team's code submission has been updated. The new code that you will use for your submission is <b>OhbVrpoiV</b>.</p>\n                <br>\n                <p>If you have any questions or concerns, please don't hesitate to reach out to us using Slack. We are here to assist you in any way that we can.</p>\n                <br>\n                <p>Thank you for your cooperation and understanding.</p>\n                <br>\n                <p>Best regards,</p>\n                <p>Panda | Technical Team<br>\n                STP</p>\n            </body>\n        </html>\n    "

# %%
context = ssl.create_default_context()

with smtplib.SMTP_SSL("smtp.gmail.com",465,context=context) as smtp:
    smtp.login(email_sender,password)
    for email in emails:
        try:
            smtp.sendmail(email_sender,email,email_string)
            print(counter)
            print(email)
            print("-------")
            counter+=1
             
            html = f'''
                    <html>
                        <body>
                            <p>Dear <b>{users[counter]}</b>,</p>
                            <p>We hope this email finds you well. I am writing to let you know that the code that will be used for your team's code submission has been updated. The new code that you will use for your submission in the leaderboard is <b>{new_code[counter]}</b> and any other code wont be accepted.</p>
                            <br>
                            <p>If you have any questions or concerns, please don't hesitate to reach out to us using Slack. We are here to assist you in any way that we can.</p>
                            <br>
                            <p>Thank you for your cooperation and understanding.</p>
                            <br>
                            <p>Best regards,</p>
                            <p>Panda | Technical Team<br>
                            STP</p>
                        </body>
                    </html>
                '''
            # Create a MIMEMultipart class, and set up the From, To, Subject fields
            email_message = MIMEMultipart()
            email_message['From'] = email_sender
            email_message['To'] = email_rec
            email_message['Subject'] = "Team Code Submission | Machathon 4.0"

            # Attach the html doc defined earlier, as a MIMEText html content type to the MIME message
            email_message.attach(MIMEText(html, "html"))

            attach_file_to_email(email_message, 'STP logo.png', {'Content-ID': '<STP>'})


            # Convert it as a string
            email_string = email_message.as_string()

            sleep(1)
        except:
            print("Error: Didnt Send")
# Out:
# 0
# Khaledhod111@gmail.com
# -------
# 1
# yaboulnour@yahoo.com
# -------
# 2
# sa.gomaa@nu.edu.eg
# -------
# 3
# abdelrahman.elhawary451@gmail.com
# -------
# 4
# salahsoliman96@gmail.com
# -------
# 5
# bedobeco90@gmail.com
# -------
# 6
# karimsabry297@gmail.com
# -------
# 7
# bassamsobhyabdaltawab@gmail.com
# -------
# 8
# ahmedmagdi8094@gmail.com
# -------
# 9
# kha.hesham@gmail.com
# -------
# 10
# 2001200@eng.asu.edu.eg
# -------
# 11
# abdelmagidmohamed89@yahoo.com
# -------
# 12
# abdelrahmanm.lotfyy@gmail.com
# -------
# 13
# kokosherif@gmail.com
# -------
# 14
# khaswas0000@gmail.com
# -------
# 15
# aminfadel2004@gmail.com
# -------
# 16
# samiryoussef903@gmail.com
# -------
# 17
# mohamedalymatar2001@gmail.com
# -------
# 18
# heshamnabil1@hotmail.com
# -------
# 19
# usefha00@gmail.com
# -------
# 20
# omaremadeldinhamed@gmail.com
# -------
# 21
# elarbawy.ah@gmail.com
# -------
# 22
# kareemnader.kn@gmail.com
# -------
# 23
# mohamed.r.5003@gmail.com
# -------
# 24
# ...

# %%
data.tail(10)
# Out:
#                       user_name       phone                         email  \
# 86                 Yahya sherif  1007206015         yahya.b2001@gmail.com
# 87             Hebat-Allah Atef  1003945224  heba.atef.muhammed@gmail.com
# 88         Zeyad tareq ramadan   1097776929         zeyadtareqr@gmail.com
# 89                  Lina Sawwan  1211880317        1900337@eng.asu.edu.eg
# 90                 Somaya Ayman         NaN      somaya189ayman@gmail.com
# 91        Abdelrahman Wael Atef         NaN  Abdelrahman-Wael@Outlook.com
# 92        Ahmed Ashraf Marzouk          NaN        a.a.elghawas@gmail.com
# 93  Mohamed Shaban Ahmed Harb           NaN      mohamedharb205@gmail.com
# 94                  Ahmed Gamal         NaN    eng.ahmedgamal52@gmail.com
# 95           David Wagih Roshdy         NaN        davidwagih62@gmail.com
#
#          faculty  graduation_year            university  \
# 86   Engineering             2023                 other
# ...
